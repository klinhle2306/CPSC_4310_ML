# %% [markdown]
# # ME1
#
#
# ## Exploratory Data Analysis
#
# - See the examples of basic visualization and Pandas on Canvas.

# %% [markdown]
# #### Write full names of your team members here.
#
# - Linh Le

# %% [markdown]
# ## Advertising data
#
# Let's take a look at some data, ask some questions about that data, and then use linear regression to answer those questions!
#
# A toy dataset for your exploratory data analysis:
#
# ./data/Advertising.csv

# %%
import pandas as pd
import numpy
import statistics as st
from matplotlib import pyplot as plt

# read CSV file stored in the current directory and save the results
data = pd.read_csv('./data/Advertising.csv', skipinitialspace=True, index_col=0)
# display the first 5 rows
data.head()
# Out:
#             TV  Radio  Newspaper  Sales
# 3/11/19  230.1   37.8       69.2   22.1
# 3/12/19   44.5   39.3       45.1   10.4
# 3/13/19   17.2   45.9       69.3    9.3
# 3/14/19  151.5   41.3       58.5   18.5
# 3/15/19  180.8   10.8       58.4   12.9

# %% [markdown]
# What are the features?
# - **TV:** advertising dollars spent on TV for a single product in a given market (in thousands of dollars)
# - **Radio:** advertising dollars spent on Radio
# - **Newspaper:** advertising dollars spent on Newspaper
#
# What is the response?
# - **Sales:** sales of a single product in a given market (in thousands of items)
#
# What else do we know?
# - Because the response variable is continuous, this is a **regression** problem.
# - There are 200 **observations** (represented by the rows), and each observation is a single market.

# %%
#display all data. You can uncomment the code in the next line

#display(data)

data.shape
# Out:
# (200, 4)

# %% [markdown]
# ## Part 1 Tasks
#
# Solve each of the following problems.
# - Check the example Python codes for data visualization and pandas DataFrame examples: EX1_pandas.zip on Week1 Synopsis in Canvas.
#
# (1) For each field of the data, what is the mean of the data? What is the median? Are there any dataset has mode value?
#
# (2) For each field of the data, give the five-number summary, minimum, the first quartile (Q1), median, the third quartile (Q3), and maximum of the data.
#
# (3) For each field of the data, visulize a boxplot of the data and compare it to your answer in (b).
#
# (4) For Sales, visualize distribution of the data using histogram. Comment on the data’s modality (i.e., bimodal, trimodal, etc.)
#
# (5) For Sales, visualize the trend of the data over time using a graph.
#
# (6) For each pair (TV-Sales, Radio-Sales, Newspaper-Sales), calculate the Pearson's correlation coefficient factor r.
#
# (7) For each pair (TV-Sales, Radio-Sales, Newspaper-Sales), visualize scatter graph.
#
# (8) Discuss what the differences are between the three: (1) boxplot, (2) histogram, and (3) scatter plot with respect to your founding.

# %%
#1
TVCost = data['TV']
RadioCost = data['Radio']
NewspaperCost = data['Newspaper']
SaleTotal = data['Sales']

print("Mean: (TV, Radio, Newspaper, Sales)")
print(st.mean(TVCost))
print(st.mean(RadioCost))
print(st.mean(NewspaperCost))
print(st.mean(SaleTotal))
print()
print("Median: (TV, Radio, Newspaper, Sales)")
print(st.median(TVCost))
print(st.median(RadioCost))
print(st.median(NewspaperCost))
print(st.median(SaleTotal))
print()
print("Mode: (TV, Radio, Newspaper, Sales)")
print(st.mode(TVCost))
print(st.mode(RadioCost))
print(st.mode(NewspaperCost))
print(st.mode(SaleTotal))
# Out:
# Mean: (TV, Radio, Newspaper, Sales)
# 147.0425
# 23.264
# 30.554
# 14.022499999999999
#
# Median: (TV, Radio, Newspaper, Sales)
# 149.75
# 22.9
# 25.75
# 12.9
#
# Mode: (TV, Radio, Newspaper, Sales)
# 17.2
# 4.1
# 9.3
# 9.7

# %%
#2
print('TV')
print('min:', min(TVCost))
print('max:', max(TVCost))
print('median:', st.median(TVCost))
print('first quartile:', numpy.quantile(TVCost, 0.25))
print('third quartile:', numpy.quantile(TVCost, 0.75))

print()
print('Radio')
print('min:', min(RadioCost))
print('max:', max(RadioCost))
print('median:', st.median(RadioCost))
print('first quartile:', numpy.quantile(RadioCost, 0.25))
print('third quartile:', numpy.quantile(RadioCost, 0.75))

print()
print('Newspaper')
print('min:', min(NewspaperCost))
print('max:', max(NewspaperCost))
print('median:', st.median(NewspaperCost))
print('first quartile:', numpy.quantile(NewspaperCost, 0.25))
print('third quartile:', numpy.quantile(NewspaperCost, 0.75))

print()
print('Sales')
print('min:', min(SaleTotal))
print('max:', max(SaleTotal))
print('median:', st.median(SaleTotal))
print('first quartile:', numpy.quantile(SaleTotal, 0.25))
print('third quartile:', numpy.quantile(SaleTotal, 0.75))
# Out:
# TV
# min: 0.7
# max: 296.4
# median: 149.75
# first quartile: 74.375
# third quartile: 218.825
#
# Radio
# min: 0.0
# max: 49.6
# median: 22.9
# first quartile: 9.975
# third quartile: 36.525
#
# Newspaper
# min: 0.3
# max: 114.0
# median: 25.75
# first quartile: 12.75
# third quartile: 45.1
#
# Sales
# min: 1.6
# max: 27.0
# median: 12.9
# first quartile: 10.375
# third quartile: 17.4

# %%
#3
plt.boxplot(data)
plt.show()

# %%
#4
plt.hist(SaleTotal)
plt.show()

# %%
#5
plt.figure(figsize=(10,10))
plt.plot(SaleTotal)

# %%
#6
print('Pearson\'s correlation coefficient factor r:')
print('TV - Sales:')
print(numpy.corrcoef(TVCost, SaleTotal)[0, 1])
print('Radio - Sales:')
print(numpy.corrcoef(RadioCost, SaleTotal)[0, 1])
print('Newspaper - Sales:')
print(numpy.corrcoef(NewspaperCost, SaleTotal)[0, 1])
# Out:
# Pearson's correlation coefficient factor r:
# TV - Sales:
# 0.7822244248616061
# Radio - Sales:
# 0.5762225745710551
# Newspaper - Sales:
# 0.22829902637616528

# %%
#7
plt.scatter(TVCost, SaleTotal)
plt.title('TV-Sales')
plt.show()

plt.scatter(RadioCost, SaleTotal)
plt.title('Radio-Sales')
plt.show()

plt.scatter(NewspaperCost, SaleTotal)
plt.title('Newspaper-Sales')
plt.show()

# %%
#8 Different graphs show us different information about the data. 
#For instance, box plot lets us know the general information about the minimum, the first quartile (Q1), median, the third quartile (Q3), and maximum of the data.
#Histogram tells us the frequency of data where scatter plot tells us the relationshp between data

# %% [markdown]
# ## Part 2
# Write a summary of what you find from the data and submit the report to CAnvas.

# %% [markdown]
# ### Resources
#
# #### Boxplot
# https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51
#
#
# - matplotlib.pyplot boxplot demo
# https://matplotlib.org/3.1.1/gallery/pyplots/boxplot_demo_pyplot.html
#
#
# #### matplotlib.pyplot
# - scatter plot
# https://matplotlib.org/3.3.2/api/_as_gen/matplotlib.pyplot.scatter.html
#
#
# - histogram plot
# https://matplotlib.org/3.3.2/api/_as_gen/matplotlib.pyplot.hist.html
#
#
# #### pandas DataFrame
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html
#
#
# - describe()
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html
#
#
# - corr()
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html
#
#
# - hist()
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.hist.html
#
#
# - plot.scatter()
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.scatter.html
#
#
# - pivot()
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.pivot.html
